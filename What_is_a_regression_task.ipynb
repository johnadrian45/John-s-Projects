# %%
'''
This is a regression task as per capita income is a continous variable with an 
uncountably infinite number of options

2.
a. False, OLS is oridnary least squares algorithm for reducing distance between
points
b. False, even if the assumptions are not met, there are ways to compensate
c. False, estimation refers to the process of determining coefficients in the train
phase while predictions are possible outcomes of a previously unseen value  
d. True
3. Target would be new dollars of new business, features would be existing services
free or not

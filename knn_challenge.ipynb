# %%
import math 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
music = pd.DataFrame()
music['duration'] = [184, 134, 243, 186, 122, 197, 294, 382, 102, 264, 
                     205, 110, 307, 110, 397, 153, 190, 192, 210, 403,
                     164, 198, 204, 253, 234, 190, 182, 401, 376, 102]
music['loudness'] = [18, 34, 43, 36, 22, 9, 29, 22, 10, 24, 
                     20, 10, 17, 51, 7, 13, 19, 12, 21, 22,
                     16, 18, 4, 23, 34, 19, 14, 11, 37, 42]
music['bpm'] = [ 105, 90, 78, 75, 120, 110, 80, 100, 105, 60,
                  70, 105, 95, 70, 90, 105, 70, 75, 102, 100,
                  100, 95, 90, 80, 90, 80, 100, 105, 70, 65]

# %%
X = music[['duration', 'loudness']]
Y = music.bpm
lr = LinearRegression()
knn = KNeighborsClassifier()

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y)
lr.fit(x_train,y_train)
knn.fit(x_train, y_train)

lr_score = lr.score(x_test, y_test)
knn_score = knn.score(X,Y)

print('Linear regression accuracy: {}'.format(lr_score))
print('KNN regression accuracy: {}'.format(knn_score))
# Out:
# Linear regression accuracy: 0.34745968850896813
# KNN regression accuracy: 0.26666666666666666
